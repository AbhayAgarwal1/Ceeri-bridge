# %% [markdown]
# # Structural health of bridge

# %% [markdown]
# ## Year 1 (all pillars)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import csv

import csv
x = []
y = []
a = []
b = []
c = []

f = open('firsty.txt')
csv_f = csv.reader(f)
i=0;
for row in csv_f:
  x.append((row[0]))
  y.append((row[1]))
  a.append((row[2]))
  b.append((row[3]))
  c.append((row[4]))
  i = i+1
  if(i > 100):
        break
  


'''plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
'''
plt.plot(x,y, label='Loaded from file!')
plt.plot(x,a, label='Loaded from file!')
plt.plot(x,b, label='Loaded from file!')
plt.plot(x,c, label='Loaded from file!')

plt.title('Data from the CSV File')
plt.xticks([])
plt.yticks([])
plt.xlabel('time')
plt.ylabel('acc (m/s2)')

plt.show()

# %%
import matplotlib.pyplot as plt
import csv

import csv
x1 = []
y1 = []
a1 = []
b1 = []
c1 = []
row =2
f = open('secondy.csv')
csv_f = csv.reader(f)
i=0;
row =2
for row in csv_f:
  x1.append((row[0]))
  y1.append((row[1]))
  a1.append((row[2]))
  b1.append((row[3]))
  c1.append((row[4]))
  i = i+1
  if i>100:
        break
  


'''plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
'''
plt.plot(x1,y1, label='Loaded from file!')
plt.plot(x1,a1, label='Loaded from file!')
plt.plot(x1,b1, label='Loaded from file!')
plt.plot(x1,c1, label='Loaded from file!')

plt.title('Data from the CSV File')
plt.xticks([])
plt.yticks([])
plt.xlabel('time')
plt.ylabel('acc (m/s2')
plt.show()

# %% [markdown]
# # Pillar 1(comarision between 1 and 2 yr)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import csv

import csv
x1 = []
y1 = []
a1 = []
b1 = []
c1 = []
row =2
f = open('secondy.csv')
csv_f = csv.reader(f)
i=0;
row =2
for row in csv_f:
  x1.append((row[0]))
  y1.append((row[1]))
  a1.append((row[2]))
  b1.append((row[3]))
  c1.append((row[4]))
  i = i+1
  if i>100:
        break
  


'''plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
'''
plt.plot(x,y, label='Loaded from file!')
plt.plot(x1,y1, label='Loaded from file!')
#plt.plot(x,b, label='Loaded from file!')
#plt.plot(x,c, label='Loaded from file!')

plt.title('Data from the CSV File')
plt.xticks([])
plt.yticks([])
plt.xlabel('time')
plt.ylabel('acc (m/s2)')

plt.show()

# %% [markdown]
# ## Pillar 2

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import csv

import csv
x1 = []
y1 = []
a1 = []
b1 = []
c1 = []
row =2
f = open('secondy.csv')
csv_f = csv.reader(f)
i=0;
row =2
for row in csv_f:
  x1.append((row[0]))
  y1.append((row[1]))
  a1.append((row[2]))
  b1.append((row[3]))
  c1.append((row[4]))
  i = i+1
  if i>100:
        break
  


'''plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
'''
plt.plot(x,y, label='Loaded from file!')
plt.plot(x1,b, label='Loaded from file!')
#plt.plot(x,b, label='Loaded from file!')
#plt.plot(x,c, label='Loaded from file!')

plt.title('Data from the CSV File')
plt.xticks([])
plt.yticks([])
plt.xlabel('time')
plt.ylabel('acc (m/s2)')

plt.show()

# %% [markdown]
# ## pillar 3

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import csv

import csv
x1 = []
y1 = []
a1 = []
b1 = []
c1 = []
row =2
f = open('secondy.csv')
csv_f = csv.reader(f)
i=0;
row =2
for row in csv_f:
  x1.append((row[0]))
  y1.append((row[1]))
  a1.append((row[2]))
  b1.append((row[3]))
  c1.append((row[4]))
  i = i+1
  if i>100:
        break
  


'''plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
'''
plt.plot(x,y, label='Loaded from file!')
plt.plot(x1,c, label='Loaded from file!')
#plt.plot(x,b, label='Loaded from file!')
#plt.plot(x,c, label='Loaded from file!')

plt.title('Data from the CSV File')
plt.xticks([])
plt.yticks([])
plt.xlabel('time')
plt.ylabel('acc (m/s2)')

plt.show()
